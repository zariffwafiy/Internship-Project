# %%
import pandas as pd
import numpy as np

from datetime import datetime

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

from pycaret.regression import * 

from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse
from statsmodels.stats.stattools import durbin_watson

# %%
file_path = "Data\\Updated_Merged_BIR_CLS.csv"
df = pd.read_csv(file_path)
df = df.drop(["BASE_DATE_1", "BOND_CODE_1"], axis = 1)

# %%
df = pd.read_csv(file_path)
print(df.head())
print(list(df.columns))
print(df.shape)
# Out:
#     BASE_DATE                                 BOND_NAME BOND_CODE  \
# 0  28/04/2023          GENM CAPITAL MTN 3652D 31.3.2027  UN170048
# 1  28/04/2023  DANUM IMTN 3.070% 21.02.2025 - Tranche 4  VI200010
# 2  28/04/2023               UEMS IMTN 5.390% 05.03.2026  VG230050
# 3  28/04/2023  DANGA IMTN 5.020% 21.09.2033 - Tranche 9  VT180093
# 4  28/04/2023            TNBPGSB IMTN 4.580% 29.03.2033  VN230073
#
#                        ISSUER_NAME  \
# 0              GENM Capital Berhad
# 1             Danum Capital Berhad
# 2               UEM Sunrise Berhad
# 3             Danga Capital Berhad
# 4  TNB Power Generation Sdn Berhad
#
#                                        FACILITY_NAME  TRADE_RECENCY  \
# 0                        GENM 20 YRS 5.0 BILLION MTN              4
# 1                DANUM RM20.0B SUKUK DANUM PROGRAMME              4
# 2  UEMS RM4.0 BILLION 7 YEARS ICP & PERPETUAL IMT...              4
# 3         DANGA RM10.0B ISLAMIC SECURITIES PROGRAMME              5
# 4  TNB Power Generation RM10.0 Billion IMTN Sukuk...              4
#
#    TRADE_FREQUENCY  TRADE_TURNOVER  COMPOSITE_LIQUIDITY_SCORE BASE_DATE_1  \
# 0                1               1                    2.00000  28/04/2023
# 1                1               4                    3.00000  28/04/2023
# 2                1               2                    2.33333  28/04/2023
# 3                1               3                    3.00000  28/04/2023
# 4                1               2                    2.33333  28/04/2023
#
#           PROD_CODE BOND_CODE_1  NOTCH_VARIANCE
# 0  UN17004831032027    UN170048               3
# 1  VI20001021022025    VI200010               0
# 2  VG23005005032026    VG230050               1
# 3  VT18009321092033    VT180093               0
# 4  VN23007329032033    VN230073               0
# ['BASE_DATE', 'BOND_NAME', 'BOND_CODE', 'ISSUER_NAME', 'FACILITY_NAME', 'TRADE_RECENCY', 'TRADE_FREQUENCY', 'TRADE_TURNOVER', 'COMPOSITE_LIQUIDITY_SCORE', 'BASE_DATE_1', 'PROD_CODE', 'BOND_CODE_1', 'NOTCH_VARIANCE']
# (65945, 13)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Remove unnecessary columns

# %%
df = df[["BASE_DATE", "BOND_CODE", "PROD_CODE", "BOND_NAME", "FACILITY_NAME", "ISSUER_NAME", "TRADE_RECENCY", "TRADE_FREQUENCY", "TRADE_TURNOVER", "COMPOSITE_LIQUIDITY_SCORE", "NOTCH_VARIANCE"]]

# %% [markdown]
# ### Rearrange for cleaner dataframe

# %%
df = df[["BASE_DATE", "BOND_CODE", "PROD_CODE", "BOND_NAME", "FACILITY_NAME", "ISSUER_NAME", "TRADE_RECENCY", "TRADE_FREQUENCY", "TRADE_TURNOVER", "COMPOSITE_LIQUIDITY_SCORE", "NOTCH_VARIANCE"]]

# %% [markdown]
# ### Remove duplicate rows

# %%
df.drop_duplicates()
# Out:
#         BASE_DATE BOND_CODE         PROD_CODE  \
# 0      28/04/2023  UN170048  UN17004831032027
# 1      28/04/2023  VI200010  VI20001021022025
# 2      28/04/2023  VG230050  VG23005005032026
# 3      28/04/2023  VT180093  VT18009321092033
# 4      28/04/2023  VN230073  VN23007329032033
# ...           ...       ...               ...
# 65940  28/04/2022  VZ120023  VZ12002311012036
# 65941  28/04/2022  UG190397  UG19039727122022
# 65942  28/04/2022  VG190296  VG19029623122022
# 65943  28/04/2022  UI200053  UI20005327022025
# 65944  28/04/2022  UN180089  UN18008925072028
#
#                                                BOND_NAME  \
# 0                       GENM CAPITAL MTN 3652D 31.3.2027
# 1               DANUM IMTN 3.070% 21.02.2025 - Tranche 4
# 2                            UEMS IMTN 5.390% 05.03.2026
# 3               DANGA IMTN 5.020% 21.09.2033 - Tranche 9
# 4                         TNBPGSB IMTN 4.580% 29.03.2033
# ...                                                  ...
# 65940  PLUS BERHAD IMTN 5.630% 11.01.2036 - Series 1 ...
# 65941  STARBRIGHT ABSMTN 1096D 27.12.2022 - Tranche N...
# 65942                AZRB CAPITAL IMTN 4.700% 23.12.2022
# 65943             TOYOTA CAP MTN 1827D 27.2.2025 - MTN 6
# 65944                              UOBM 4.80% 25.07.2028
#
#                                            FACILITY_NAME  \
# 0                            GENM 20 YRS 5.0 BILLION MTN
# 1                    DANUM RM20.0B SUKUK DANUM PROGRAMME
# 2      UEMS RM4.0 BILLION 7 YEARS ICP & PERPETUAL IMT...
# 3             DANGA RM10.0B ISLAMIC SECURITIES PROGRAMME
# 4      TNB Power Generation RM10.0 Billion IMTN Sukuk...
# ...                                                  ...
# 65940        PLUS BERHAD RM23.35 BILLION SUKUK PROGRAMME
# 65941               STARBRIGHT RM665.0M ASSET-BACKED MTN
# 65942  AZRB CAPITAL RM535.0 MILLION 12-YEARS SUKUK MU...
# 65943                TOYOTA CAPITAL RM2.5B MTN PROGRAMME
# 65944  Medium Term Notes (MTN) Programme of RM8.0 bil...
#
#                                   ISSUER_NAME  TRADE_RECENCY  TRADE_FREQUENCY  \
# 0                         GENM Capital Berhad              4                1
# 1                        Danum Capital Berhad              4                1
# 2                          UEM Sunrise Berhad              4                1
# 3                        Danga Capital Berhad              5                1
# 4             TNB Power Generation Sdn Berhad              4                1
# ...                                       ...            ...              ...
# 65940       Projek Lebuhraya Usahasama Berhad              5                1
# 65941               Starbright Capital Berhad              4                1
# 65942                 AZRB Capital Sdn Berhad              4                1
# 65943      Toyota Capital Malaysia Sdn Berhad              5                1
# 65944  United Overseas Bank (Malaysia) Berhad              4                1
#
#        TRADE_TURNOVER  COMPOSITE_LIQUIDITY_SCORE  NOTCH_VARIANCE
# 0                   1                    2.00000               3
# 1                   4                    3.00000               0
# 2                   2                    2.33333               1
# 3                   3                    3.00000               0
# 4                   2                    2.33333               0
# ...               ...                        ...             ...
# 65940               1                    2.33333               0
# 65941               3                    2.66667               4
# 65942               3                    2.66667               1
# 65943               5                    3.66667               3
# 65944               4                    3.00000               1
#
# [65945 rows x 11 columns]

# %% [markdown]
# ### Sort values by increasing date

# %%
df["BASE_DATE"] = pd.to_datetime(df["BASE_DATE"], format = '%d/%m/%Y')
df.sort_values(by = ["BASE_DATE"], ascending = True, inplace = True)

# %% [markdown]
# Given that the latest base date available is 28/04/2023, the YTD will be from 28/04/2022 - 28/04/2023

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Dataset summary

# %%
df.describe()
# Out:
#        TRADE_RECENCY  TRADE_FREQUENCY  TRADE_TURNOVER  \
# count   65945.000000     65945.000000    65945.000000
# mean        4.373842         1.186959        3.307044
# std         0.484139         0.466648        1.497739
# min         3.000000         1.000000        1.000000
# 25%         4.000000         1.000000        2.000000
# 50%         4.000000         1.000000        4.000000
# 75%         5.000000         1.000000        5.000000
# max         5.000000         5.000000        5.000000
#
#        COMPOSITE_LIQUIDITY_SCORE  NOTCH_VARIANCE
# count               65945.000000    65945.000000
# mean                    2.955948        0.222352
# std                     0.574899        1.434985
# min                     1.666670       -6.000000
# 25%                     2.333330       -1.000000
# 50%                     3.000000        0.000000
# 75%                     3.333330        1.000000
# max                     5.000000        6.000000

# %% [markdown]
# ### Dataset shape

# %%
df.shape
# Out:
# (65945, 11)

# %% [markdown]
# ### Dataset general info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65945 entries, 65944 to 0
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   BASE_DATE                  65945 non-null  datetime64[ns]
#  1   BOND_CODE                  65945 non-null  object
#  2   PROD_CODE                  65945 non-null  object
#  3   BOND_NAME                  65945 non-null  object
#  4   FACILITY_NAME              65945 non-null  object
#  5   ISSUER_NAME                65945 non-null  object
#  6   TRADE_RECENCY              65945 non-null  int64
#  7   TRADE_FREQUENCY            65945 non-null  int64
#  8   TRADE_TURNOVER             65945 non-null  int64
#  9   COMPOSITE_LIQUIDITY_SCORE  65945 non-null  float64
#  10  NOTCH_VARIANCE             65945 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 6.0+ MB

# %% [markdown]
# ### Dependant variable : Notch Variance

# %%
df.NOTCH_VARIANCE.unique()
# Out:
# array([ 1,  0, -3, -1,  3,  4,  2, -2,  5, -4, -5, -6,  6], dtype=int64)

# %%
df.NOTCH_VARIANCE.value_counts()
# Out:
#  0    27101
# -1    12212
#  1     9178
#  2     6831
#  3     3818
# -2     3555
# -3     1745
#  4     1210
#  5      125
# -4      114
# -5       25
#  6       19
# -6       12
# Name: NOTCH_VARIANCE, dtype: int64

# %% [markdown]
# ### Dependant variable : Composite Liquidity Score

# %%
df.COMPOSITE_LIQUIDITY_SCORE.unique()
# Out:
# array([3.     , 3.66667, 3.33333, 2.66667, 2.     , 2.33333, 4.     ,
#        4.66667, 4.33333, 5.     , 1.66667])

# %%
df.COMPOSITE_LIQUIDITY_SCORE.value_counts()
# Out:
# 3.33333    16366
# 3.00000    11881
# 2.66667     9568
# 2.33333     9343
# 3.66667     8045
# 2.00000     7635
# 4.00000     2516
# 4.33333      496
# 4.66667       74
# 5.00000       17
# 1.66667        4
# Name: COMPOSITE_LIQUIDITY_SCORE, dtype: int64

# %% [markdown]
# ### Boxplots

# %%
boxplot = df.boxplot(column = ["NOTCH_VARIANCE", "COMPOSITE_LIQUIDITY_SCORE"])
plt.title("Boxplot of Notch Variance and Composite Liquidity Score")
# Out:
# Text(0.5, 1.0, 'Boxplot of Notch Variance and Composite Liquidity Score')

# %%
boxplot_sns = sns.boxplot(data = df[["NOTCH_VARIANCE", "COMPOSITE_LIQUIDITY_SCORE"]])
plt.title("Boxplot of Notch Variance and Composite Liquidity Score")
plt.xlabel("Features")
plt.ylabel("Values")
plt.xticks(rotation = 45)
sns.set_style("whitegrid")

# %% [markdown]
# ### KDE plot

# %%
included_df = df[["NOTCH_VARIANCE", "TRADE_RECENCY", "TRADE_FREQUENCY", "TRADE_TURNOVER", "COMPOSITE_LIQUIDITY_SCORE"]]
for col in included_df.columns: 
    fig, ax = plt.subplots(figsize = (8, 6))
    
    sns.kdeplot(data = df[col], ax =ax
               )
    
    ax.set_title(f"KDE Plot - {col}")
    ax.set_xlabel(col)
    ax.set_ylabel("Density")
    
    plt.show()

# %% [markdown]
# # Analytics

# %% [markdown]
# ### Find correlation of variables, no dropping dependant variables (Correlation Matrix @ Correlation Heatmap)

# %%
plt.figure(figsize = (16, 6))
heatmap = sns.heatmap(df[["NOTCH_VARIANCE", "TRADE_RECENCY", "TRADE_FREQUENCY", "TRADE_TURNOVER", "COMPOSITE_LIQUIDITY_SCORE"]].corr(), vmin = -1, vmax = 1, annot = True, cmap = "BrBG")
heatmap.set_title("Correlation Heatmap", fontdict= {
    "fontsize" : 16
}, pad = 12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# The notch variance does not show a strong correlation with the composite liquidity score
#
# **keep in note that :
#     * lower notch variance means that the BIR is better than credit rating
#     * higher notch variance means that the BIR is worse than credit rating**

# %% [markdown]
# *Observe that there is a strong positive correlation between notch variance and outstanding amount,
# the higher the oustanding amount, the higher the notch_variance (dated)
#
# *Meaning that when the bond is recently introduced in the primary market with high oustanding amount, the price of bonds will be much closer with the credit rating, which makes sense.(dated)

# %%
print(df["BOND_CODE"].value_counts().head(1))
# Out:
# PZ200004    242
# Name: BOND_CODE, dtype: int64

# %% [markdown]
# chosen bond : bond code = PZ200004

# %%
chosen_bond_code = "PZ200004"
data = df.loc[df["BOND_CODE"] == chosen_bond_code]
plot_df = df[df["BOND_CODE"] == chosen_bond_code].sort_values(by = ["BASE_DATE"], ascending = True)
plot_df = plot_df[["BASE_DATE", "NOTCH_VARIANCE", "COMPOSITE_LIQUIDITY_SCORE"]]

# %%
fig, ax = plt.subplots(figsize = (10, 5))
plot_df.plot(x = "BASE_DATE", y = ["NOTCH_VARIANCE", "COMPOSITE_LIQUIDITY_SCORE"], kind = "line", ax = ax)
plt.xlabel("Values")
start_date = ""
plt.ylabel("Date")
plt.xticks(rotation = 45)
plt.title("Notch Variance and Composite Liqudity Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# observe the correlation between notch variance and composite liquidity score

# %%
print(plot_df["NOTCH_VARIANCE"].corr(plot_df["COMPOSITE_LIQUIDITY_SCORE"]))
# Out:
# 0.0506583730879393

# %% [markdown]
# ### Relation of dependant variable between multiple bonds

# %%
top_3_modes = df["BOND_CODE"].value_counts().head(3)
print(top_3_modes)
# Out:
# PZ200004    242
# PZ190011    240
# UF210196    236
# Name: BOND_CODE, dtype: int64

# %%
bond_code_1 = "PZ200004"
bond_code_2 = "VZ120024"
bond_code_3 = "VK160112"

df1 = df[df["BOND_CODE"] == bond_code_1].sort_values(by = ["BASE_DATE"], ascending = True)
df2 = df[df["BOND_CODE"] == bond_code_2].sort_values(by = ["BASE_DATE"], ascending = True)
df3 = df[df["BOND_CODE"] == bond_code_3].sort_values(by = ["BASE_DATE"], ascending = True)

# %% [markdown]
# ### Composite Liquidity Score

# %%
bond_code_1 = "PZ200004"
bond_code_2 = "VZ120024"
bond_code_3 = "VK160112"

df1 = df[df["BOND_CODE"] == bond_code_1].sort_values(by = ["BASE_DATE"], ascending = True)
df2 = df[df["BOND_CODE"] == bond_code_2].sort_values(by = ["BASE_DATE"], ascending = True)
df3 = df[df["BOND_CODE"] == bond_code_3].sort_values(by = ["BASE_DATE"], ascending = True)

# %% [markdown]
# ### Notch Variance

# %%
plt.plot(df1["BASE_DATE"], df1["NOTCH_VARIANCE"], label= bond_code_1)
plt.plot(df2["BASE_DATE"], df2["NOTCH_VARIANCE"], label= bond_code_2)
plt.plot(df3["BASE_DATE"], df3["NOTCH_VARIANCE"], label= bond_code_3)
plt.ylabel("Values")
plt.xticks(rotation = 45)
plt.title("Notch Variance Score of 5 Different Bonds")
plt.tight_layout()
plt.legend()
plt.show()

# %%
df["BASE_DATE"] = pd.to_datetime(df["BASE_DATE"], format = '%d/%m/%Y')
df.sort_values(by = ["BASE_DATE"], ascending = True, inplace = True)
chosen_bond_code = "PZ200004"
new_data = df.loc[df["BOND_CODE"] == chosen_bond_code]
new_data = new_data[["BASE_DATE", "NOTCH_VARIANCE", "COMPOSITE_LIQUIDITY_SCORE"]]
new_data = new_data.set_index("BASE_DATE")
print(new_data)
# Out:
#             NOTCH_VARIANCE  COMPOSITE_LIQUIDITY_SCORE
# BASE_DATE
# 2022-04-28              -1                    4.66667
# 2022-04-29              -1                    4.33333
# 2022-05-05              -1                    4.33333
# 2022-05-06              -1                    4.66667
# 2022-05-09              -1                    4.33333
# ...                    ...                        ...
# 2023-04-20               2                    4.33333
# 2023-04-25               2                    4.00000
# 2023-04-26               2                    4.00000
# 2023-04-27               2                    4.00000
# 2023-04-28               2                    4.00000
#
# [242 rows x 2 columns]

# %% [markdown]
# ### Differentiate when needed

# %%
# differentiate only NOTCH_VARIANCE and not COMPOSITE_LIQUIDITY_SCORE
df_diff = new_data.copy()
df_diff["NOTCH_VARIANCE"] = df_diff["NOTCH_VARIANCE"].diff()
df_diff["NOTCH_VARIANCE"].fillna(df_diff["NOTCH_VARIANCE"].mode()[0], inplace = True)
print(df_diff)
# Out:
#             NOTCH_VARIANCE  COMPOSITE_LIQUIDITY_SCORE
# BASE_DATE
# 2022-04-28             0.0                    4.66667
# 2022-04-29             0.0                    4.33333
# 2022-05-05             0.0                    4.33333
# 2022-05-06             0.0                    4.66667
# 2022-05-09             0.0                    4.33333
# ...                    ...                        ...
# 2023-04-20             0.0                    4.33333
# 2023-04-25             0.0                    4.00000
# 2023-04-26             0.0                    4.00000
# 2023-04-27             0.0                    4.00000
# 2023-04-28             0.0                    4.00000
#
# [242 rows x 2 columns]

# %% [markdown]
# ### Selecting the suitable lag order

# %%
p = 100

for i in range(1, p+1):
    model = VAR(df_diff)
    results = model.fit(i)
    print(f'VAR Order {i}')
    print('AIC {}'.format(results.aic))
    print('BIC {}'.format(results.bic))
    print()
# Out:
# VAR Order 1
# AIC -7.063934590941576
# BIC -6.977176161062141
#
# VAR Order 2
# AIC -7.030535394851619
# BIC -6.885508773045703
#
# VAR Order 3
# AIC -6.9914551966644165
# BIC -6.787812980233282
#
# VAR Order 4
# AIC -6.964473376071072
# BIC -6.701864669658944
#
# VAR Order 5
# AIC -6.927018727792911
# BIC -6.605089094438595
#
# VAR Order 6
# AIC -6.886151789127915
# BIC -6.504543200438653
#
# VAR Order 7
# AIC -6.845378285030299
# BIC -6.403729070458704
#
# VAR Order 8
# AIC -6.804334500545559
# BIC -6.302279295749995
#
# VAR Order 9
# AIC -6.767291507028147
# BIC -6.204461201296402
#
# VAR Order 10
# AIC -6.759396982425395
# BIC -6.135418665140977
#
# VAR Order 11
# AIC -6.732458187138223
# BIC -6.046955093268083
#
# VAR Order 12
# AIC -6.716640919022669
# BIC -5.969232373604583
#
# VAR Order 13
# AIC -6.731229342457163
# BIC -5.92153070406446
#
# VAR Order 14
# AIC -6.750248478709937
# BIC -5.87787108187065
#
# VAR Order 15
# AIC -6.728018309340049
# BIC -5.7925694058869786
#
# VAR Order 16
# AIC -6.726954067752102
# BIC -5.728036767079663
#
# VAR Order 17
# AIC -6.691757790989584
# BIC -5.628970999192653
#
# VAR Order 18
# AIC -6.65271397813439
# BIC -5.525652336003707
#
# VAR Order 19
# AIC -6.608944408425391
# BIC -5.417198228273422
#
# VAR Order 20
# AIC -6.617305199983791
# BIC -5.36046040127421
#
# VAR Order 21
# AIC -6.599773795823716
# BIC -5.277411839576988
#
# VAR Order 22
# AIC -6.559976244444957
# BIC -5.171674066391718
#
# VAR Order 23
# AIC -6.553064776256215
# BIC -5.0983947187094065
#
# VAR Order 24
# AIC -6.614144321952078
# BIC -5.092674064367992
#
# VAR Order 25
# AIC -6.600525817714625
# BIC -5.011818305912197
#
# VAR Order 26
# AIC -6.565732410246644
# BIC -4.909345784253489
#
# VAR Order 27
# AIC -6.541117512435857
# BIC -4.816605032928681
#
# VAR Order 28
# AIC -6.517728205559035
# BIC -4.724638178865151
#
# VAR Order 29
# AIC -6.485785156686021
# BIC -4.623660858311785
#
# VAR Order 30
# AIC -6.467103965021869
# BIC -4.535483561672881
#
# VAR Order 31
# AIC -6.420388246909064
# BIC -4.41880471696601
#
# VAR Order 32
# AIC -6.383508108141082
# BIC -4.3114891605540775
#
# VAR Order 33
# AIC -6.359883724424203
# BIC -4.216951715987435
#
# VAR Order 34
# AIC -6.317902980341881
# BIC -4.103574831309276
#
# VAR Order 35
# AIC -6.29565824784915
# BIC -4.009445355850684
#
# VAR Order 36
# AIC -6.282266498991062
# BIC -3.923674651208155
#
# VAR Order 37
# AIC -6.302201318886546
# BIC -3.8707306024438086
#
# VAR Order 38
# AIC -6.3430419171444345
# BIC -3.8381866276738013
#
# VAR Order 39
# AIC -6.30769443108363
# BIC -3.7289429794156383
#
# VAR Order 40
# AIC -6.262670680433432
# BIC -3.6095054973691
#
# VAR Order 41
# AIC -6.226777262113852
# BIC -3.498674701229242
#
# VAR Order 42
# AIC -6.22288601248117
# BIC -3.4193162509153394
#
# VAR Order 43
# AIC -6.1945195677213745
# BIC -3.3149465048969438
#
# VAR Order 44
# AIC -6.18178266393172
# BIC -3.2256638181558257
#
# VAR Order 45
# AIC -6.133220276456083
# BIC -3.1000066793478904
#
# VAR Order 46
# AIC -6.109793773408361
# BIC -2.9989298620977687
#
# VAR Order 47
# AIC -6.078484565041933
# BIC -2.889408072082385
#
# VAR Order 48
# AIC -6.056606215642232
# BIC -2.7887480565789033
#
# VAR Order 49
# AIC -6.028496816887374
# BIC -2.6812809754201865
#
# VAR Order 50
# AIC -6.093312253316128
# BIC -2.666155663995232
#
# VAR Order 51
# AIC -6.100015391432917
# BIC -2.5923278198224153
#
# VAR Order 52
# AIC -6.223235759176629
# BIC -2.6344196794203016
#
# VAR Order 53
# AIC -6.3237087388827415
# BIC -2.6531592086035696
#
# VAR Order 54
# AIC -6.323128727722675
# BIC -2.5702332601858187
#
# VAR Order 55
# AIC -6.275290453850048
# BIC -2.4394288873167946
#
# VAR Order 56
# AIC -6.24407902826534
# BIC -2.324623392463277
#
# VAR Order 57
# AIC -6.242554664634631
# BIC -2.238869044266985
#
# VAR Order 58
# AIC -6.213464879014165
# BIC -2.124905274228823
#
# VAR Order 59
# AIC -6.197117441220826
# BIC -2.0230316249571194
#
# VAR Order 60
# AIC -6.193537746571443
# BIC -1.9332651187001
#
# VAR Order 61
# AIC -6.180479265256749
# BIC -1.8333507034258467
#
# VAR Order 62
# AIC -6.600286905745352
# BIC -2.165624612842282
#
# VAR Order 63
# AIC -6.67492333620044
# BIC -2.152040684337022
#
# VAR Order 64
# AIC -7.129016184895084
# BIC -2.5172175558200403
#
# VAR Order 65
# AIC -7.106320820651513
# BIC -2.404901442491382
#
# VAR Order 66
# AIC -7.064837226826462
# BIC -2.273083007052893
#
# VAR Order 67
# AIC -7.055128191857122
# BIC -2.1723155463751285
#
# VAR Order 68
# AIC -7.052626597668852
# BIC -2.078022275917238
#
# VAR Order 69
# AIC -7.216354240408844
# BIC -2.1492151463603903
#
# VAR Order 70
# AIC -7.278001268982024
# BIC -2.1175742779274103
#
# VAR Order 71
# AIC -7.282673338700669
# BIC -2.0281951096962203
#
# VAR Order 72
# AIC -7.570776721311603
# BIC -2.2214735051670385
#
# VAR Order 73
# AIC -7.980163488218396
# BIC -2.5352509308966003
#
# VAR Order 74
# AIC -7.994196965755279
# BIC -2.45287990705188
#
# VAR Order 75
# AIC -8.367446670933106
# BIC -2.7289189382992127
#
# VAR Order 76
# AIC -8.857294327142938
# BIC -3.1207385245097914
#
# VAR Order 77
# AIC -9.181375056227495
# BIC -3.34596234768701
#
# VAR Order 78
# AIC -10.217588587306706
# BIC -4.28247847549696
#
# VAR Order 79
# AIC -10.503464454789167
# BIC -4.467804553828737
#
# VAR Order 80
# AIC -48.164525423368055
# BIC -42.02745122617776
#
# VAR Order 81
# AIC -124.30232272445507
# BIC -118.06295736430019
#
# VAR Order 82
# AIC -125.21130142139657
# BIC -118.8687554274768
#
# VAR Order 83
# AIC -123.79768659063464
# BIC -117.35105763754308
#
# VAR Order 84
# AIC -123.52678195254742
# BIC -116.97515460341378
#
# VAR Order 85
# AIC -123.63065459394339
# BIC -116.97310003707001
#
# VAR Order 86
# AIC -125.09394415927454
# BIC -118.32951993806724
#
# VAR Order 87
# AIC -125.41963813894422
# BIC -118.54738787493302
#
# VAR Order 88
# AIC -122.17053549949534
# BIC -115.18948860823284
#
# VAR Order 89
# AIC -124.89622651908135
# BIC -117.80539791869904
#
# VAR Order 90
# AIC -126.04391553845959
# BIC -118.84230535065463
#
# VAR Order 91
# AIC -120.6800627973422
# BIC -113.36665604055901
#
# VAR Order 92
# AIC -122.2847064784566
# BIC -114.85847275301917
#
# VAR Order 93
# AIC -125.19152240295242
# BIC -117.65141556789467
#
# VAR Order 94
# AIC -125.2463602950428
# BIC -117.59131813637501
#
# VAR Order 95
# AIC -126.8796458262767
# BIC -119.1085897164163
#
# VAR Order 96
# AIC -126.47197387269834
# BIC -118.58380842078452
#
# VAR Order 97
# AIC -125.29754658940593
# BIC -117.29115928220577
#
# VAR Order 98
# AIC -126.26058842628157
# BIC -118.13484925938613
#
# VAR Order 99
# AIC -126.91279466510755
# BIC -118.66655576410446
#
# VAR Order 100
# AIC -128.17185974171412
# BIC -119.80395497301195

# %% [markdown]
# We can see that the lag order 61 will give lowest values of BIC and AIC. Both AIC and BIC punishes overfitting by providing increasing values
#
# Here are few items to take note:
# * BIC tend to penalize complex models, suggests a simpler model that still fits the data well.
# * AIC tend to favor them, indicates a relatively more complex model that provides a good fit to the data.
#
# The AIC tends to favor more complex models, including models with higher lag orders, as it puts less penalty on the number of parameters. Therefore, if your primary goal is to have a more flexible and complex model that captures potential long-term dependencies and dynamics in the data, you may consider selecting the lag order that corresponds to the lowest AIC value.
#
# However, it's important to note that a more complex model may not always lead to better forecasting performance. A higher lag order could also introduce noise or overfitting, especially if you have limited data or if the relationships among the variables are not well-defined.
#
# The BIC, on the other hand, penalizes complex models more heavily by taking into account the sample size. It tends to prefer simpler models with fewer parameters. If your goal is to balance model complexity and overfitting while still obtaining good forecasting performance, you may consider selecting the lag order that corresponds to the lowest BIC value.

# %%
selected_order = model.select_order(maxlags = 60)
p = selected_order.bic
print("Selected Order (P) of VAR model: ", p)
# Out:
# Selected Order (P) of VAR model:  1

# %% [markdown]
# The selected order is 0, but it does not reflect the aic values which is highest at 0, so we will go will the lag order of 61

# %%
lag_order = 61
results = model.fit(lag_order)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 20, Jun, 2023
# Time:                     15:08:15
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -1.83335
# Nobs:                     181.000    HQIC:                  -4.41806
# Log likelihood:           291.678    FPE:                 0.00375172
# AIC:                     -6.18048    Det(Omega_mle):      0.00132996
# --------------------------------------------------------------------
# Results for equation NOTCH_VARIANCE
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                                -0.463065         0.245097           -1.889           0.059
# L1.NOTCH_VARIANCE                    -0.226922         0.132020           -1.719           0.086
# L1.COMPOSITE_LIQUIDITY_SCORE         -0.037862         0.076880           -0.492           0.622
# L2.NOTCH_VARIANCE                    -0.207361         0.135886           -1.526           0.127
# L2.COMPOSITE_LIQUIDITY_SCORE         -0.041482         0.095339           -0.435           0.663
# L3.NOTCH_VARIANCE                    -0.037510         0.136968           -0.274           0.784
# L3.COMPOSITE_LIQUIDITY_SCORE          0.011553         0.095957            0.120           0.904
# L4.NOTCH_VARIANCE                    -0.191354         0.138598           -1.381           0.167
# L4.COMPOSITE_LIQUIDITY_SCORE          0.063641         0.098175            0.648           0.517
# L5.NOTCH_VARIANCE                    -0.343621         0.136513           -2.517           0.012
# L5.COMPOSITE_LIQUIDITY_SCORE         -0.062425         0.098768           -0.632           0.527
# L6.NOTCH_VARIANCE                    -0.244434         0.140677           -1.738           0.082
# L6.COMPOSITE_LIQUIDITY_SCORE         -0.083357         0.101486           -0.821           0.411
# L7.NOTCH_VARIANCE                    -0.155245         0.142909           -1.086           0.277
# L7.COMPOSITE_LIQUIDITY_SCORE         -0.027720         0.102244           -0.271           0.786
# L8.NOTCH_VARIANCE                    -0.161383         0.139507           -1.157           0.247
# L8.COMPOSITE_LIQUIDITY_SCORE          0.078920         0.100706            0.784           0.433
# L9.NOTCH_VARIANCE                    -0.294205         0.148532           -1.981           0.048
# L9.COMPOSITE_LIQUIDITY_SCORE          0.177689         0.097034            1.831           0.067
# L10.NOTCH_VARIANCE                   -0.417220         0.146393           -2.850           0.004
# L10.COMPOSITE_LIQUIDITY_SCORE        -0.048795         0.090185           -0.541           0.588
# L11.NOTCH_VARIANCE                   -0.230403         0.151878           -1.517           0.129
# L11.COMPOSITE_LIQUIDITY_SCORE         0.072074         0.086470            0.834           0.405
# L12.NOTCH_VARIANCE                   -0.163348         0.149832           -1.090           0.276
# L12.COMPOSITE_LIQUIDITY_SCORE        -0.260805         0.087243           -2.989           0.003
# L13.NOTCH_VARIANCE                   -0.150111         0.144773           -1.037           0.300
# L13.COMPOSITE_LIQUIDITY_SCORE         0.083171         0.092229            0.902           0.367
# L14.NOTCH_VARIANCE                   -0.302547         0.146903           -2.060           0.039
# L14.COMPOSITE_LIQUIDITY_SCORE         0.013679         0.091619            0.149           0.881
# L15.NOTCH_VARIANCE                   -0.456827         0.147957           -3.088           0.002
# L15.COMPOSITE_LIQUIDITY_SCORE         0.065061         0.092161            0.706           0.480
# L16.NOTCH_VARIANCE                   -0.411411         0.164517           -2.501           0.012
# L16.COMPOSITE_LIQUIDITY_SCORE         0.071396         0.091647            0.779           0.436
# L17.NOTCH_VARIANCE                   -0.384403         0.177799           -2.162           0.031
# L17.COMPOSITE_LIQUIDITY_SCORE        -0.066165         0.090524           -0.731           0.465
# L18.NOTCH_VARIANCE                   -0.325982         0.183636           -1.775           0.076
# L18.COMPOSITE_LIQUIDITY_SCORE         0.000694         0.089103            0.008           0.994
# L19.NOTCH_VARIANCE                   -0.304525         0.192218           -1.584           0.113
# L19.COMPOSITE_LIQUIDITY_SCORE         0.178076         0.088075            2.022           0.043
# L20.NOTCH_VARIANCE                   -0.299894         0.185357           -1.618           0.106
# L20.COMPOSITE_LIQUIDITY_SCORE        -0.092206         0.091107           -1.012           0.312
# L21.NOTCH_VARIANCE                   -0.380217         0.178853           -2.126           0.034
# L21.COMPOSITE_LIQUIDITY_SCORE        -0.015771         0.091987           -0.171           0.864
# L22.NOTCH_VARIANCE                   -0.317183         0.180229           -1.760           0.078
# L22.COMPOSITE_LIQUIDITY_SCORE        -0.115503         0.091491           -1.262           0.207
# L23.NOTCH_VARIANCE                   -0.447727         0.183340           -2.442           0.015
# L23.COMPOSITE_LIQUIDITY_SCORE         0.034902         0.091950            0.380           0.704
# L24.NOTCH_VARIANCE                   -0.372348         0.193189           -1.927           0.054
# L24.COMPOSITE_LIQUIDITY_SCORE         0.119434         0.092117            1.297           0.195
# L25.NOTCH_VARIANCE                   -0.457608         0.200052           -2.287           0.022
# L25.COMPOSITE_LIQUIDITY_SCORE         0.046558         0.094534            0.492           0.622
# L26.NOTCH_VARIANCE                   -0.388302         0.200518           -1.936           0.053
# L26.COMPOSITE_LIQUIDITY_SCORE         0.019035         0.093720            0.203           0.839
# L27.NOTCH_VARIANCE                   -0.296090         0.200562           -1.476           0.140
# L27.COMPOSITE_LIQUIDITY_SCORE        -0.166355         0.091078           -1.827           0.068
# L28.NOTCH_VARIANCE                   -0.288694         0.193715           -1.490           0.136
# L28.COMPOSITE_LIQUIDITY_SCORE         0.003474         0.094719            0.037           0.971
# L29.NOTCH_VARIANCE                   -0.277738         0.197260           -1.408           0.159
# L29.COMPOSITE_LIQUIDITY_SCORE         0.076157         0.093016            0.819           0.413
# L30.NOTCH_VARIANCE                   -0.395409         0.194323           -2.035           0.042
# L30.COMPOSITE_LIQUIDITY_SCORE        -0.008206         0.095138           -0.086           0.931
# L31.NOTCH_VARIANCE                   -0.455568         0.192010           -2.373           0.018
# L31.COMPOSITE_LIQUIDITY_SCORE         0.007023         0.098525            0.071           0.943
# L32.NOTCH_VARIANCE                   -0.406106         0.196901           -2.062           0.039
# L32.COMPOSITE_LIQUIDITY_SCORE         0.000287         0.094180            0.003           0.998
# L33.NOTCH_VARIANCE                   -0.382327         0.196619           -1.945           0.052
# L33.COMPOSITE_LIQUIDITY_SCORE         0.025471         0.091721            0.278           0.781
# L34.NOTCH_VARIANCE                   -0.221624         0.200932           -1.103           0.270
# L34.COMPOSITE_LIQUIDITY_SCORE         0.115610         0.094115            1.228           0.219
# L35.NOTCH_VARIANCE                   -0.333625         0.188679           -1.768           0.077
# L35.COMPOSITE_LIQUIDITY_SCORE        -0.048908         0.094056           -0.520           0.603
# L36.NOTCH_VARIANCE                   -0.149205         0.209311           -0.713           0.476
# L36.COMPOSITE_LIQUIDITY_SCORE        -0.062890         0.093907           -0.670           0.503
# L37.NOTCH_VARIANCE                   -0.166621         0.203135           -0.820           0.412
# L37.COMPOSITE_LIQUIDITY_SCORE        -0.034543         0.092887           -0.372           0.710
# L38.NOTCH_VARIANCE                   -0.233690         0.195553           -1.195           0.232
# L38.COMPOSITE_LIQUIDITY_SCORE         0.015787         0.082346            0.192           0.848
# L39.NOTCH_VARIANCE                   -0.150604         0.194004           -0.776           0.438
# L39.COMPOSITE_LIQUIDITY_SCORE         0.082927         0.078963            1.050           0.294
# L40.NOTCH_VARIANCE                   -0.310823         0.195660           -1.589           0.112
# L40.COMPOSITE_LIQUIDITY_SCORE         0.030702         0.078888            0.389           0.697
# L41.NOTCH_VARIANCE                   -0.410630         0.195419           -2.101           0.036
# L41.COMPOSITE_LIQUIDITY_SCORE         0.030388         0.078131            0.389           0.697
# L42.NOTCH_VARIANCE                   -0.283869         0.203797           -1.393           0.164
# L42.COMPOSITE_LIQUIDITY_SCORE        -0.050590         0.077019           -0.657           0.511
# L43.NOTCH_VARIANCE                   -0.167745         0.195286           -0.859           0.390
# L43.COMPOSITE_LIQUIDITY_SCORE        -0.058693         0.076906           -0.763           0.445
# L44.NOTCH_VARIANCE                    0.050909         0.190447            0.267           0.789
# L44.COMPOSITE_LIQUIDITY_SCORE         0.027418         0.077304            0.355           0.723
# L45.NOTCH_VARIANCE                   -0.097985         0.182468           -0.537           0.591
# L45.COMPOSITE_LIQUIDITY_SCORE        -0.068320         0.077475           -0.882           0.378
# L46.NOTCH_VARIANCE                   -0.230109         0.179348           -1.283           0.199
# L46.COMPOSITE_LIQUIDITY_SCORE         0.096542         0.077965            1.238           0.216
# L47.NOTCH_VARIANCE                   -0.340227         0.179489           -1.896           0.058
# L47.COMPOSITE_LIQUIDITY_SCORE        -0.032366         0.077694           -0.417           0.677
# L48.NOTCH_VARIANCE                   -0.188869         0.181928           -1.038           0.299
# L48.COMPOSITE_LIQUIDITY_SCORE        -0.012071         0.083356           -0.145           0.885
# L49.NOTCH_VARIANCE                   -0.182757         0.169588           -1.078           0.281
# L49.COMPOSITE_LIQUIDITY_SCORE         0.029195         0.085099            0.343           0.732
# L50.NOTCH_VARIANCE                   -0.058672         0.164126           -0.357           0.721
# L50.COMPOSITE_LIQUIDITY_SCORE         0.018439         0.083757            0.220           0.826
# L51.NOTCH_VARIANCE                   -0.218007         0.158643           -1.374           0.169
# L51.COMPOSITE_LIQUIDITY_SCORE         0.085665         0.079934            1.072           0.284
# L52.NOTCH_VARIANCE                   -0.195624         0.140342           -1.394           0.163
# L52.COMPOSITE_LIQUIDITY_SCORE        -0.107281         0.079466           -1.350           0.177
# L53.NOTCH_VARIANCE                   -0.205858         0.145183           -1.418           0.156
# L53.COMPOSITE_LIQUIDITY_SCORE        -0.067526         0.079477           -0.850           0.396
# L54.NOTCH_VARIANCE                   -0.290038         0.146286           -1.983           0.047
# L54.COMPOSITE_LIQUIDITY_SCORE         0.047550         0.079236            0.600           0.548
# L55.NOTCH_VARIANCE                   -0.139378         0.152349           -0.915           0.360
# L55.COMPOSITE_LIQUIDITY_SCORE         0.077529         0.081319            0.953           0.340
# L56.NOTCH_VARIANCE                   -0.272184         0.159405           -1.708           0.088
# L56.COMPOSITE_LIQUIDITY_SCORE         0.063831         0.082260            0.776           0.438
# L57.NOTCH_VARIANCE                   -0.156626         0.163336           -0.959           0.338
# L57.COMPOSITE_LIQUIDITY_SCORE        -0.090644         0.081692           -1.110           0.267
# L58.NOTCH_VARIANCE                   -0.229367         0.162660           -1.410           0.159
# L58.COMPOSITE_LIQUIDITY_SCORE        -0.031897         0.081958           -0.389           0.697
# L59.NOTCH_VARIANCE                   -0.211171         0.161230           -1.310           0.190
# L59.COMPOSITE_LIQUIDITY_SCORE        -0.031739         0.079908           -0.397           0.691
# L60.NOTCH_VARIANCE                   -0.106684         0.157853           -0.676           0.499
# L60.COMPOSITE_LIQUIDITY_SCORE         0.048703         0.082004            0.594           0.553
# L61.NOTCH_VARIANCE                   -0.014075         0.152959           -0.092           0.927
# L61.COMPOSITE_LIQUIDITY_SCORE         0.011566         0.069429            0.167           0.868
# ================================================================================================
#
# Results for equation COMPOSITE_LIQUIDITY_SCORE
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                                -0.422075         0.410111           -1.029           0.303
# L1.NOTCH_VARIANCE                     0.009027         0.220903            0.041           0.967
# L1.COMPOSITE_LIQUIDITY_SCORE          0.743951         0.128640            5.783           0.000
# L2.NOTCH_VARIANCE                    -0.216433         0.227372           -0.952           0.341
# L2.COMPOSITE_LIQUIDITY_SCORE          0.153249         0.159527            0.961           0.337
# L3.NOTCH_VARIANCE                    -0.338599         0.229183           -1.477           0.140
# L3.COMPOSITE_LIQUIDITY_SCORE          0.073865         0.160560            0.460           0.645
# L4.NOTCH_VARIANCE                    -0.174558         0.231910           -0.753           0.452
# L4.COMPOSITE_LIQUIDITY_SCORE         -0.068814         0.164272           -0.419           0.675
# L5.NOTCH_VARIANCE                    -0.079011         0.228421           -0.346           0.729
# L5.COMPOSITE_LIQUIDITY_SCORE          0.097366         0.165264            0.589           0.556
# L6.NOTCH_VARIANCE                    -0.081881         0.235389           -0.348           0.728
# L6.COMPOSITE_LIQUIDITY_SCORE         -0.074482         0.169813           -0.439           0.661
# L7.NOTCH_VARIANCE                    -0.286143         0.239123           -1.197           0.231
# L7.COMPOSITE_LIQUIDITY_SCORE         -0.062993         0.171080           -0.368           0.713
# L8.NOTCH_VARIANCE                    -0.655585         0.233430           -2.808           0.005
# L8.COMPOSITE_LIQUIDITY_SCORE         -0.128472         0.168507           -0.762           0.446
# L9.NOTCH_VARIANCE                    -0.400551         0.248533           -1.612           0.107
# L9.COMPOSITE_LIQUIDITY_SCORE         -0.039817         0.162363           -0.245           0.806
# L10.NOTCH_VARIANCE                   -0.494483         0.244952           -2.019           0.044
# L10.COMPOSITE_LIQUIDITY_SCORE        -0.057451         0.150903           -0.381           0.703
# L11.NOTCH_VARIANCE                   -0.556766         0.254132           -2.191           0.028
# L11.COMPOSITE_LIQUIDITY_SCORE         0.222452         0.144687            1.537           0.124
# L12.NOTCH_VARIANCE                   -0.345104         0.250707           -1.377           0.169
# L12.COMPOSITE_LIQUIDITY_SCORE        -0.007614         0.145980           -0.052           0.958
# L13.NOTCH_VARIANCE                   -0.306312         0.242242           -1.264           0.206
# L13.COMPOSITE_LIQUIDITY_SCORE         0.037274         0.154324            0.242           0.809
# L14.NOTCH_VARIANCE                   -0.216661         0.245806           -0.881           0.378
# L14.COMPOSITE_LIQUIDITY_SCORE         0.060620         0.153302            0.395           0.693
# L15.NOTCH_VARIANCE                   -0.460719         0.247570           -1.861           0.063
# L15.COMPOSITE_LIQUIDITY_SCORE        -0.063065         0.154209           -0.409           0.683
# L16.NOTCH_VARIANCE                   -0.520827         0.275280           -1.892           0.058
# L16.COMPOSITE_LIQUIDITY_SCORE        -0.028189         0.153350           -0.184           0.854
# L17.NOTCH_VARIANCE                   -0.508149         0.297504           -1.708           0.088
# L17.COMPOSITE_LIQUIDITY_SCORE         0.079989         0.151470            0.528           0.597
# L18.NOTCH_VARIANCE                   -0.833326         0.307270           -2.712           0.007
# L18.COMPOSITE_LIQUIDITY_SCORE         0.107699         0.149092            0.722           0.470
# L19.NOTCH_VARIANCE                   -0.529563         0.321630           -1.646           0.100
# L19.COMPOSITE_LIQUIDITY_SCORE         0.054405         0.147372            0.369           0.712
# L20.NOTCH_VARIANCE                   -0.889387         0.310149           -2.868           0.004
# L20.COMPOSITE_LIQUIDITY_SCORE        -0.246769         0.152446           -1.619           0.106
# L21.NOTCH_VARIANCE                   -0.585173         0.299267           -1.955           0.051
# L21.COMPOSITE_LIQUIDITY_SCORE         0.114360         0.153919            0.743           0.457
# L22.NOTCH_VARIANCE                   -0.534262         0.301569           -1.772           0.076
# L22.COMPOSITE_LIQUIDITY_SCORE        -0.048752         0.153088           -0.318           0.750
# L23.NOTCH_VARIANCE                   -0.681802         0.306775           -2.222           0.026
# L23.COMPOSITE_LIQUIDITY_SCORE         0.002827         0.153856            0.018           0.985
# L24.NOTCH_VARIANCE                   -0.760494         0.323254           -2.353           0.019
# L24.COMPOSITE_LIQUIDITY_SCORE         0.021334         0.154136            0.138           0.890
# L25.NOTCH_VARIANCE                   -0.938299         0.334738           -2.803           0.005
# L25.COMPOSITE_LIQUIDITY_SCORE         0.065408         0.158180            0.414           0.679
# L26.NOTCH_VARIANCE                   -0.728039         0.335518           -2.170           0.030
# L26.COMPOSITE_LIQUIDITY_SCORE         0.095039         0.156817            0.606           0.544
# L27.NOTCH_VARIANCE                   -0.632355         0.335591           -1.884           0.060
# L27.COMPOSITE_LIQUIDITY_SCORE         0.155982         0.152398            1.024           0.306
# L28.NOTCH_VARIANCE                   -0.795946         0.324134           -2.456           0.014
# L28.COMPOSITE_LIQUIDITY_SCORE        -0.108672         0.158489           -0.686           0.493
# L29.NOTCH_VARIANCE                   -0.636219         0.330067           -1.928           0.054
# L29.COMPOSITE_LIQUIDITY_SCORE         0.166161         0.155640            1.068           0.286
# L30.NOTCH_VARIANCE                   -0.169596         0.325152           -0.522           0.602
# L30.COMPOSITE_LIQUIDITY_SCORE        -0.384517         0.159191           -2.415           0.016
# L31.NOTCH_VARIANCE                   -0.512793         0.321282           -1.596           0.110
# L31.COMPOSITE_LIQUIDITY_SCORE         0.175369         0.164858            1.064           0.287
# L32.NOTCH_VARIANCE                   -0.526460         0.329466           -1.598           0.110
# L32.COMPOSITE_LIQUIDITY_SCORE        -0.047693         0.157587           -0.303           0.762
# L33.NOTCH_VARIANCE                   -0.797721         0.328995           -2.425           0.015
# L33.COMPOSITE_LIQUIDITY_SCORE         0.093065         0.153473            0.606           0.544
# L34.NOTCH_VARIANCE                   -0.672234         0.336211           -1.999           0.046
# L34.COMPOSITE_LIQUIDITY_SCORE         0.107421         0.157479            0.682           0.495
# L35.NOTCH_VARIANCE                   -0.627252         0.315709           -1.987           0.047
# L35.COMPOSITE_LIQUIDITY_SCORE         0.014547         0.157380            0.092           0.926
# L36.NOTCH_VARIANCE                   -0.596387         0.350232           -1.703           0.089
# L36.COMPOSITE_LIQUIDITY_SCORE         0.035851         0.157130            0.228           0.820
# L37.NOTCH_VARIANCE                   -0.549341         0.339897           -1.616           0.106
# L37.COMPOSITE_LIQUIDITY_SCORE        -0.061909         0.155424           -0.398           0.690
# L38.NOTCH_VARIANCE                   -0.355156         0.327210           -1.085           0.278
# L38.COMPOSITE_LIQUIDITY_SCORE        -0.094891         0.137786           -0.689           0.491
# L39.NOTCH_VARIANCE                   -0.563366         0.324619           -1.735           0.083
# L39.COMPOSITE_LIQUIDITY_SCORE         0.085910         0.132126            0.650           0.516
# L40.NOTCH_VARIANCE                   -0.314327         0.327389           -0.960           0.337
# L40.COMPOSITE_LIQUIDITY_SCORE        -0.039022         0.132000           -0.296           0.768
# L41.NOTCH_VARIANCE                   -0.546193         0.326987           -1.670           0.095
# L41.COMPOSITE_LIQUIDITY_SCORE         0.130529         0.130733            0.998           0.318
# L42.NOTCH_VARIANCE                   -0.174357         0.341005           -0.511           0.609
# L42.COMPOSITE_LIQUIDITY_SCORE        -0.020311         0.128873           -0.158           0.875
# L43.NOTCH_VARIANCE                    0.022436         0.326764            0.069           0.945
# L43.COMPOSITE_LIQUIDITY_SCORE        -0.078360         0.128683           -0.609           0.543
# L44.NOTCH_VARIANCE                   -0.216716         0.318666           -0.680           0.496
# L44.COMPOSITE_LIQUIDITY_SCORE         0.104953         0.129350            0.811           0.417
# L45.NOTCH_VARIANCE                   -0.077621         0.305316           -0.254           0.799
# L45.COMPOSITE_LIQUIDITY_SCORE        -0.124742         0.129636           -0.962           0.336
# L46.NOTCH_VARIANCE                   -0.165536         0.300094           -0.552           0.581
# L46.COMPOSITE_LIQUIDITY_SCORE        -0.144402         0.130456           -1.107           0.268
# L47.NOTCH_VARIANCE                   -0.105488         0.300330           -0.351           0.725
# L47.COMPOSITE_LIQUIDITY_SCORE         0.120758         0.130003            0.929           0.353
# L48.NOTCH_VARIANCE                   -0.526863         0.304413           -1.731           0.083
# L48.COMPOSITE_LIQUIDITY_SCORE         0.108370         0.139477            0.777           0.437
# L49.NOTCH_VARIANCE                   -0.434704         0.283765           -1.532           0.126
# L49.COMPOSITE_LIQUIDITY_SCORE         0.045034         0.142392            0.316           0.752
# L50.NOTCH_VARIANCE                   -0.428988         0.274626           -1.562           0.118
# L50.COMPOSITE_LIQUIDITY_SCORE        -0.051471         0.140147           -0.367           0.713
# L51.NOTCH_VARIANCE                   -0.144005         0.265451           -0.542           0.587
# L51.COMPOSITE_LIQUIDITY_SCORE        -0.081138         0.133750           -0.607           0.544
# L52.NOTCH_VARIANCE                   -0.578458         0.234828           -2.463           0.014
# L52.COMPOSITE_LIQUIDITY_SCORE         0.001253         0.132967            0.009           0.992
# L53.NOTCH_VARIANCE                    0.058638         0.242929            0.241           0.809
# L53.COMPOSITE_LIQUIDITY_SCORE        -0.039917         0.132985           -0.300           0.764
# L54.NOTCH_VARIANCE                   -0.028828         0.244774           -0.118           0.906
# L54.COMPOSITE_LIQUIDITY_SCORE         0.077651         0.132582            0.586           0.558
# L55.NOTCH_VARIANCE                   -0.015058         0.254919           -0.059           0.953
# L55.COMPOSITE_LIQUIDITY_SCORE        -0.101353         0.136067           -0.745           0.456
# L56.NOTCH_VARIANCE                   -0.255156         0.266725           -0.957           0.339
# L56.COMPOSITE_LIQUIDITY_SCORE        -0.025317         0.137642           -0.184           0.854
# L57.NOTCH_VARIANCE                   -0.014602         0.273303           -0.053           0.957
# L57.COMPOSITE_LIQUIDITY_SCORE         0.167466         0.136691            1.225           0.221
# L58.NOTCH_VARIANCE                   -0.236371         0.272173           -0.868           0.385
# L58.COMPOSITE_LIQUIDITY_SCORE         0.068088         0.137137            0.496           0.620
# L59.NOTCH_VARIANCE                   -0.394084         0.269779           -1.461           0.144
# L59.COMPOSITE_LIQUIDITY_SCORE         0.035800         0.133707            0.268           0.789
# L60.NOTCH_VARIANCE                   -0.125278         0.264129           -0.474           0.635
# L60.COMPOSITE_LIQUIDITY_SCORE        -0.159959         0.137214           -1.166           0.244
# L61.NOTCH_VARIANCE                   -0.383684         0.255940           -1.499           0.134
# L61.COMPOSITE_LIQUIDITY_SCORE        -0.001228         0.116172           -0.011           0.992
# ================================================================================================
#
# Correlation matrix of residuals
#                              NOTCH_VARIANCE  COMPOSITE_LIQUIDITY_SCORE
# NOTCH_VARIANCE                     1.000000                  -0.037813
# COMPOSITE_LIQUIDITY_SCORE         -0.037813                   1.000000

# %% [markdown]
# ### Forecasting

# %%
z = results.forecast(y = df_diff.values[-lag_order:], steps = 60)
index = pd.date_range(start='29/4/2023',periods=60,freq='D')
df_forecast = pd.DataFrame(z, index = index, columns = df_diff.columns)
print(df_forecast)
# Out:
#             NOTCH_VARIANCE  COMPOSITE_LIQUIDITY_SCORE
# 2023-04-29        0.376163                   3.908238
# 2023-04-30        0.230106                   3.815543
# 2023-05-01        0.059871                   4.140791
# 2023-05-02        0.230313                   4.134389
# 2023-05-03       -0.033701                   4.374278
# 2023-05-04       -0.234707                   4.283638
# 2023-05-05       -0.047079                   4.652566
# 2023-05-06        0.042917                   5.181712
# 2023-05-07        0.304898                   5.217349
# 2023-05-08        0.013404                   5.430916
# 2023-05-09       -0.132920                   5.335167
# 2023-05-10       -0.152862                   5.148794
# 2023-05-11       -0.070825                   4.798765
# 2023-05-12       -0.021212                   4.758508
# 2023-05-13        0.071915                   4.551603
# 2023-05-14        0.009418                   4.565888
# 2023-05-15       -0.017930                   3.910204
# 2023-05-16        0.036623                   4.043138
# 2023-05-17       -0.062646                   4.068721
# 2023-05-18        0.048107                   4.057776
# 2023-05-19        0.010748                   4.044937
# 2023-05-20        0.081822                   4.304236
# 2023-05-21        0.015628                   4.364693
# 2023-05-22       -0.021343                   4.166626
# 2023-05-23        0.045402                   4.286599
# 2023-05-24        0.153538                   4.049025
# 2023-05-25        0.249205                   4.278060
# 2023-05-26        0.094086                   4.236272
# 2023-05-27        0.306163                   4.165766
# 2023-05-28        0.040333                   4.084908
# 2023-05-29        0.074932                   4.134696
# 2023-05-30       -0.067950                   4.268344
# 2023-05-31       -0.026884                   4.258684
# 2023-06-01       -0.070846                   4.436600
# 2023-06-02       -0.077864                   4.293720
# 2023-06-03       -0.038515                   4.270974
# 2023-06-04        0.057448                   4.240402
# 2023-06-05        0.153122                   4.003630
# 2023-06-06       -0.008971                   4.309689
# 2023-06-07        0.051583                   4.120171
# 2023-06-08        0.030483                   4.108071
# 2023-06-09       -0.005245                   3.944592
# 2023-06-10       -0.008525                   4.016869
# 2023-06-11        0.046726                   4.181699
# 2023-06-12        0.017951                   4.215126
# 2023-06-13        0.003289                   4.100426
# 2023-06-14        0.039936                   4.199103
# 2023-06-15        0.029142                   4.024655
# 2023-06-16       -0.061508                   3.707388
# 2023-06-17       -0.143559                   3.536684
# 2023-06-18       -0.110245                   3.291002
# 2023-06-19       -0.016402                   3.277686
# 2023-06-20        0.062583                   2.854512
# 2023-06-21        0.100076                   2.608901
# 2023-06-22       -0.053108                   2.492200
# 2023-06-23       -0.009833                   2.410265
# 2023-06-24       -0.050260                   2.509775
# 2023-06-25        0.078380                   2.864885
# 2023-06-26        0.103750                   3.021729
# 2023-06-27        0.042010                   3.105993

# %% [markdown]
# ### Invert the differenced timeseries back if necessary

# %%
df_forecast['NOTCH_VARIANCE'] = (df['NOTCH_VARIANCE'].iloc[-1]) + df_forecast['NOTCH_VARIANCE'].cumsum()

# %%
# Create subplots for NOTCH_VARIANCE and COMPOSITE_LIQUIDITY_SCORE
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8))

# Plot for NOTCH_VARIANCE
axes[0].plot(new_data.index, new_data["NOTCH_VARIANCE"], label="Train (Actual)", color='blue')
axes[0].plot(df_forecast.index, df_forecast["NOTCH_VARIANCE"], label="Forecast", color='orange')
axes[0].set_xlabel("Date")
axes[0].set_ylabel("NOTCH_VARIANCE")
axes[0].set_title("Forecast vs Actuals - NOTCH_VARIANCE")
axes[0].legend()
axes[0].grid(True)

# Plot for COMPOSITE_LIQUIDITY_SCORE
axes[1].plot(new_data.index, new_data["COMPOSITE_LIQUIDITY_SCORE"], label="Train (Actual)", color='blue')
axes[1].plot(df_forecast.index, df_forecast["COMPOSITE_LIQUIDITY_SCORE"], label="Forecast", color='orange')
axes[1].set_xlabel("Date")
axes[1].set_ylabel("COMPOSITE_LIQUIDITY_SCORE")
axes[1].set_title("Forecast vs Actuals - COMPOSITE_LIQUIDITY_SCORE")
axes[1].legend()
axes[1].grid(True)

# Connect the lines between the last point of "Train (Actual)" and the first point of "Forecast"
axes[0].plot([new_data.index[-1], df_forecast.index[0]], [new_data["NOTCH_VARIANCE"].iloc[-1], df_forecast["NOTCH_VARIANCE"].iloc[0]], color='orange', linestyle='-')
axes[1].plot([new_data.index[-1], df_forecast.index[0]], [new_data["COMPOSITE_LIQUIDITY_SCORE"].iloc[-1], df_forecast["COMPOSITE_LIQUIDITY_SCORE"].iloc[0]], color='orange', linestyle='-')

plt.tight_layout()
plt.show()
